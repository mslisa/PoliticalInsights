# %% [markdown]
# ### Extremely Minimum Viable Product, Part 2
#
# Depending on the address of the voter-to-be in the first part of our eMVP, we will have 2 additional informative nuggets to share.
#
# Still to be tweaked: how do we get the information... by rep id first and then by name? Hopefully that works.

# %%
import warnings
from IPython.display import Image
# %matplotlib inline

# %%
#Financial Data
#This uses the rep id....
# !python -W ignore fincamp.py "S6CA00584"

# %%
Image('findata.png')

# %%
#Public Perception
#This uses the person's name

# !python -W ignore publicperception.py "S6CA00584"
# Out:
# Public Perception of  Kamala Harris
#
# Total tweets: 5500
# Positive tweets percentage: 34 %
# Negative tweets percentage: 10 %
# Neutral tweets percentage: 54 %
#
# Topics:
#
# 1  -  Water Resources Development  :  1 tweet(s).
# 2  -  Native Americans  :  1 tweet(s).
# 3  -  Housing and Community Development  :  1 tweet(s).
# 4  -  Emergency Management  :  3 tweet(s).
# 5  -  Government Operations and Politics  :  3 tweet(s).
# 6  -  Crime and Law Enforcement  :  1 tweet(s).
# 7  -  Civil Rights and Liberties, Minority Issues  :  2 tweet(s).
# 8  -  Money :  6 tweet(s).
# 9  -  News :  1 tweet(s).
# 10  -  Labor and Employment  :  1 tweet(s).
# 11  -  Environmental Protection  :  1 tweet(s).
# 12  -  Left :  1 tweet(s).

# %%
Image(filename='word_cloud.png')
